# %%
corpus="""Hello world! This is a sample text for testing the code. It contains multiple sentences, punctuation, and various words to analyze. Let's see how well the code can process this text and extract meaningful information from it."""

# %%
print(corpus)
# Out:
# Hello world! This is a sample text for testing the code. It contains multiple sentences, punctuation, and various words to analyze. Let's see how well the code can process this text and extract meaningful information from it.

# %%
##Tokenization
##Sentence --> paragraphs, sentences, words, characters
from nltk.tokenize import sent_tokenize, word_tokenize,wordpunct_tokenize 
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 ##Tokenization
#       2 ##Sentence --> paragraphs, sentences, words, characters
#       3 from nltk.tokenize import sent_tokenize, word_tokenize,wordpunct_tokenize
# ----> 4 nltk.download('punkt')
#       5 nltk.download('punkt_tab')
#
# NameError: name 'nltk' is not defined

# %%
documents = sent_tokenize(corpus)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 documents = sent_tokenize(corpus)
#
# File c:\Users\ratho\AppData\Local\Programs\Python\Python314\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File c:\Users\ratho\AppData\Local\Programs\Python\Python314\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
# ...

# %%
print(documents)
type(documents)

# %%
for sent in documents:
    print(sent)
    print("\n")

# %%
## Tokenization of words
## paragraphs --> sentences --> words --> characters
for sent in documents:
    words = word_tokenize(sent)
    print(words)
    print("\n")
